# %% [markdown]
# # 🔥 cuda-path-to-flash — Kaggle Runner
#
# Clone the repo, pick an exercise, run it. That's it.
#
# **Make sure GPU is enabled**: Settings → Accelerator → GPU

# %%
# !nvidia-smi
import torch
print(f"PyTorch: {torch.__version__}, CUDA: {torch.version.cuda}, GPU: {torch.cuda.get_device_name(0)}")

# %%
# Clone repo (only needs to run once)
# !git clone https://github.com/demolemo/cuda-path-to-flash.git 2>/dev/null || (cd cuda-path-to-flash && git pull)
# %cd cuda-path-to-flash

# %%
# Run a specific exercise:
# Change the path to whatever you're working on

# Module 01
# !python 01-gpu-basics/exercises/01_hello_gpu.py

# %%
# Run with benchmarks
# !CUDA_BENCH=1 python 01-gpu-basics/exercises/02_vector_add.py

# %%
# Or use the runner to run an entire module:
# !python run.py 01

# %%
# Quick edit: modify a kernel right here, then run
# (or just edit on your Mac, git push, git pull here)

# Example: peek at an exercise
# !head -40 01-gpu-basics/exercises/01_hello_gpu.py

# %% [markdown]
# ## Workflow
#
# 1. **On your Mac**: edit `.py` files, `git push`
# 2. **Here**: `!cd cuda-path-to-flash && git pull && python run.py 01/01`
# 3. See ✅ or ❌, iterate
#
# Or edit directly in this notebook and copy back to repo when done.
